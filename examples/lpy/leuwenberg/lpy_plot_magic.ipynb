# %%
import pgljupyter

# %%
# %lpy_plot?
# Out:
# Docstring: <no docstring>
# File:      ~/jvail/plantgl-jupyter/pgljupyter/magics.py

# %%
# %lpy_plot leuwenberg.lpy -c 50 -s 500,400
# Out:
# SceneWidget(scenes=[{'id': '5vUH225poiZXfTYPOZkR4Z1fN', 'data': b'x\xdaSLrw\xf5\xf7e`Pp\xe0\xe5RPVVd\x00\x020\…
