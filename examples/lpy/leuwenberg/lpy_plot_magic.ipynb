# %%
import pgljupyter

# %%
# %lpy_plot?

# %%
# %lpy_plot leuwenberg.lpy -c 50 -s 500,400
# Out:
# SceneWidget(scenes=[{'id': 'e008LRqp5BudtbS3YAU5X0ypD', 'data': b'x\xdaSLrw\xf5\xf7e`Pp\xe0\xe5RPVVd\x00\x020\…
