# %%
import pgljupyter

# %%
# %lpy_plot?
# Out:
# Docstring:
# ::
#
#   %lpy_plot [--size SIZE]
#                 [--cell CELL]
#                 file
#
# positional arguments:
#   file             L-Py file path
#
# optional arguments:
#   --size SIZE, -s SIZE
#                    Width and hight of
#                    the canvas
#   --cell CELL, -c CELL
#                    Size of cell for a
#                    single derivation
#                    step
# File:      ~/git/jvail/plantgl-jupyter/pgljupyter/magics.py

# %%
# %lpy_plot leuwenberg.lpy -c 50 -s 500,400
# Out:
# SceneWidget(scenes=[{'id': 'u0H9hc8oMLO3WEIQy4VdbACCr', 'data': b'x\xdaSLrw\xf5\xf7e`Pp\xe0\xe5RPVVd\x00\x020\…
